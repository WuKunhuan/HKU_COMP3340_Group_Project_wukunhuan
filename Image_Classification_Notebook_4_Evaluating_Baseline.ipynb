# %% [markdown]
# # COMP3340 Group Project Notebook 4
#
# ## Evaluate Model Performance
#
# Task: Image Classification with Oxford 17 Flower Dataset
#
# Author: Wu Kunhuan, and other group members

# %% [markdown]
# ------
#
# ## <font color='red'>**SETUP**</font>
#
# Please select <font color='red'>ONE of the following methods</font> to setup the notebook.

# %% [markdown]
# ### <font color='red'>Upload Local Files (for Colab Users)</font>

# %% [markdown]
# First of all, setup a folder in Colab and put all the files including this notebook inside.
#
# Change the local path in Colab (By default, if you see "sample_data" in the sidebar, that means the current path is "/content").
#
# For example, if all the files are in the "COMP3340_GP" folder in the same level of "sample_data", then the path is "/content/COMP3340_GP".

# %%
import os
path = "/content/COMP3340_GP"
project_dir = path; os.chdir(project_dir)
# !ls  # You should see the files inside the folder if you state the right path.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8febe6a23994> in <cell line: 3>()
#       1 import os
#       2 path = "/content/COMP3340_GP"
# ----> 3 project_dir = path; os.chdir(project_dir)
#       4 get_ipython().system('ls  # You should see the files inside the folder if you state the right path.')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/COMP3340_GP'

# %% [markdown]
# ### <font color='red'>Mount with Google Drive (for Google Drive Colab Users)</font>

# %% [markdown]
# Use the below cell to shut down Google Drive Kernel when necessary:

# %% [markdown]
# Grant the access to your Google Drive:

# %%
get_ipython().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = "/content/drive/My Drive/Colab Projects/COMP3340_GP"
# plz manually specify the project directory
project_dir = path; os.chdir(project_dir)
# !ls  # You should see the files inside the folder if you state the right path.
# Out:
# codes
# configurations
# datasets
# figures
# Image_Classification_Notebook_1_Introduction.ipynb
# Image_Classification_Notebook_2_Setup.ipynb
# Image_Classification_Notebook_3_Training.ipynb
# Image_Classification_Notebook_4_Evaluating_Baseline.ipynb
# models
# Notebook_Draft.ipynb
# README.md
# shared
# trained_models

# %% [markdown]
# ### <font color='red'>Other Users</font>

# %% [markdown]
# Other Users are those who run this notebook without Colab (e.g., run with VSCode, or Jupyter Lab with local servers)
#
# You may skip the setup. Please ensure the below Module Setup codes output the right directory path (automatically detected). If not so, change the setup.path manually:
#
# ```GP_setup.path = CORRECT_PATH_TO_YOUR_FOLDER```

# %% [markdown]
# <br/><br/>
# # Module Setup
#
# This Setup will download required packages by itself.

# %%
import codes.setup as setup
GP_setup = setup.setup()

import codes.import_dataset as import_dataset
import codes.model as model
import codes.experiment as experiment
# Out:
# Start setting up ... (this may take some time to download packages)
#
# Path: /content/drive/My Drive/Colab Projects/COMP3340_GP
# [Package] install pip successfully.
# [Package] import pytorch successfully.
# [Package] import numpy successfully.
# [Package] import torchvision successfully.
# [Package] import scikit-learn successfully.
# [Package] import seaborn successfully.
# [Package] import pandas successfully.
# [Package] install zip successfully.
# [Package] install unzip successfully.
# [Package] install wget successfully.
#
# COMP3340_GP setup finished.

# %% [markdown]
# ------

# %% [markdown]
# # Import Dataset

# %%
import codes.Oxford_17_Dataset as Oxford
import codes.setup_default_dataset as setup_dataset
setup_dataset.setup_default_dataset(GP_setup)

import codes.import_dataset as import_dataset
dataset = import_dataset.import_dataset (GP_setup, "Oxford_17")
# Out:
# The default Oxford_17 dataset ALREADY EXISTS.
# COMP3340_GP default datasets are all created.
# Current datasets: ['My_dataset', 'Oxford_17']
# Importing dataset Oxford_17 ... Finished
# A total of 1088 train, 136 val and 136 test images.

# %% [markdown]
# # 1. Train Results
#
# Note that the current selection only subject to what we have achieved in the course period. Once better results are achieved, we will update the sections correspondingly.

# %% [markdown]
# ## 1.1 AlexNet

# %% [markdown]
# **ALEXNET** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|16|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.801|
# |Latest Val Acc (Top 5)|0.963|
# |Latest Train Loss|2.095|

# %%
model.model(GP_setup, dataset, 
            "AlexNet", "CrossEntropyLoss", "Adam", 
            0.0001, 0.9, 50, 16, "AlexNet_lr1e-4_b16_e50", False)

# %% [markdown]
# ## 1.2 VGG

# %% [markdown]
# **VGG** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Mode Type|VGG 11|
# |Learning Rate|0.0001|
# |Batch Size|16|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
# NOTE THAT we did not get optimal result due to limited computational resources.

# %%
model.model(GP_setup, dataset, 
            "VGG_11", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 16, "VGG_11_lr1e-4_b16_e100", False)

# %% [markdown]
# ## 1.3 ResNet

# %% [markdown]
# **RESNET** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Model Typle|ResNet 18|
# |Learning Rate|0.001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.860|
# |Latest Train Loss|56.466|

# %%
model.model(GP_setup, dataset, 
            "ResNet_18", "CrossEntropyLoss", "Adam", 
            0.001, None, 50, 4, "ResNet_18_lr1e-4_b4_e50", False)

# %% [markdown]
# ## 1.4 Inception V1

# %% [markdown]
# **INCEPTION V1** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.684|
# |Latest Train Loss|90.459|

# %%
model.model(GP_setup, dataset, 
            "Inception_V1", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 4, "Inception_V1_lr1e-4_b4_e50", False)

# %% [markdown]
# ## 1.5 Inception V4

# %% [markdown]
# **INCEPTION V4** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.729|
# |Latest Train Loss|184.16|

# %%
model.model(GP_setup, dataset, 
            "Inception_V4", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 4, "Inception_V4_lr1e-4_b4_e50", False)

# %% [markdown]
# ## 1.5 Inception V4

# %% [markdown]
# **INCEPTION V4** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.729|
# |Latest Train Loss|184.16|

# %%
model.model(GP_setup, dataset, 
            "Inception_V4", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 4, "Inception_V4_lr1e-4_b4_e50", False)

# %% [markdown]
# ## 1.5 Inception V4

# %% [markdown]
# **INCEPTION V4** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.729|
# |Latest Train Loss|184.16|

# %%
model.model(GP_setup, dataset, 
            "Inception_V4", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 4, "Inception_V4_lr1e-4_b4_e50", False)

# %% [markdown]
# ## 1.5 Inception V4

# %% [markdown]
# **INCEPTION V4** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.729|
# |Latest Train Loss|184.16|

# %%
model.model(GP_setup, dataset, 
            "Inception_V4", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 4, "Inception_V4_lr1e-4_b4_e50", False)

# %% [markdown]
# ## 1.5 Inception V4

# %% [markdown]
# **INCEPTION V4** on the Original Oxford 17 Dataset
#
# Hyper-parameters:
#
# |Parameter|Value|
# |-|-|
# |Learning Rate|0.0001|
# |Batch Size|4|
# |Loss Function|Cross Entropy|
# |Optimizer|Adam|
# |Epoches|50|
#
#
# What we achieved:
#
# |KPI|Result|
# |-|-|
# |Latest Val Acc|0.729|
# |Latest Train Loss|184.16|

# %%
model.model(GP_setup, dataset, 
            "Inception_V4", "CrossEntropyLoss", "Adam", 
            0.0001, None, 50, 4, "Inception_V4_lr1e-4_b4_e50", False)

# %% [markdown]
# # 2. Experiments
#
# Select the model folders in the ```trained_models``` folder to import for the experiments.

# %% [markdown]
# There are already different trained models being uploaded in the ```trained_models``` folder.
#
# After the previous training step, you may have additional saved models. Load models for different experiments.
#
# ------
#
# **POSSIBLE EXPERIMENTS**
#
# Conduct different experiments with imported models. Independent variables:
#
# * Learning Rates
# * Batch Sizes
# * Datasets
# * Backbones
# * Pre-trained or not
# * Optimizers
# * etc.
#
# ------

# %% [markdown]
# ## 2.1 Models of different Learning Rates

# %% [markdown]
# Load the trained models:

# %%
AlexNet_lr1e_5 = model.model.load_model (model.model_schema(), GP_setup, "AlexNet_lr1e-5_b16_e50")
AlexNet_lr3e_5 = model.model.load_model (model.model_schema(), GP_setup, "AlexNet_lr3e-5_b16_e50")
AlexNet_lr1e_4 = model.model.load_model (model.model_schema(), GP_setup, "AlexNet_lr1e-4_b16_e50")
AlexNet_lr3e_4 = model.model.load_model (model.model_schema(), GP_setup, "AlexNet_lr3e-4_b16_e50")
# Out:
# ...
# Load model AlexNet_lr1e-5_b16_e50 (AlexNet) successfully.
# ...
# Load model AlexNet_lr3e-5_b16_e50 (AlexNet) successfully.
# ...
# Load model AlexNet_lr1e-4_b16_e50 (AlexNet) successfully.
# ...
# Load model AlexNet_lr3e-4_b16_e50 (AlexNet) successfully.

# %% [markdown]
# ### Learning Rates -> Train Losses

# %% [markdown]
# ------
#
# Evaluate the change of training losses of the same model with different learning rates:

# %%
experiment.Experiment(AlexNet_lr1e_5, AlexNet_lr3e_5, AlexNet_lr1e_4, AlexNet_lr3e_4).\
    model_trainloss(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between models and Train Losses & Validation Accuracies (top 1 & top 5).
#
# ...
#
# Consider the above warning(s), press Enter to discard or enter anything to continue drawing the chart. 1
# [Controlled Variables]
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 1e-05
# epoch: 50
# batch size: 16
#
# train loss:
# [192.431, 176.559, 160.762, 155.113, 152.52, 147.089, 142.265, 134.459, 132.359, 125.431, 120.692, 118.453, 116.679, 110.218, 106.49, 102.235, 94.857, 91.292, 89.942, 89.87, 86.0, 84.559, 80.43, 79.152, 78.234, 72.684, 74.077, 72.088, 68.053, 68.535, 66.447, 64.436, 61.522, 63.883, 59.0, 58.313, 56.951, 56.401, 54.968, 52.918, 51.332, 50.27, 52.914, 49.396, 48.46, 47.227, 44.695, 47.945, 44.368, 44.743]
# ...

# %% [markdown]
# ### Learning Rates -> Validation Accurcies (Top 1)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 1) of the same model with different learning rates:

# %%
experiment.Experiment(AlexNet_lr1e_5, AlexNet_lr3e_5, AlexNet_lr1e_4, AlexNet_lr3e_4).\
    lr_valacc1(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Learning Rates & Validation Accuracies (top 1).
#
# [Controlled Variables]
# model: AlexNet
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# epoch: 50
# batch size: 16
#
# learning rate: ['1e-05', '3e-05', '0.0001', '0.0003']
# validation accuracy (top 1):
# [0.074, 0.154, 0.199, 0.206, 0.191, 0.331, 0.294, 0.309, 0.287, 0.338, 0.324, 0.338, 0.404, 0.412, 0.456, 0.544, 0.441, 0.551, 0.485, 0.588, 0.574, 0.581, 0.581, 0.603, 0.632, 0.647, 0.61, 0.618, 0.618, 0.64, 0.669, 0.669, 0.64, 0.691, 0.699, 0.691, 0.699, 0.647, 0.699, 0.699, 0.684, 0.669, 0.706, 0.662, 0.721, 0.75, 0.684, 0.706, 0.721, 0.662]
# ...

# %% [markdown]
# ### Learning Rates -> Validation Accurcies (Top 5)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 5) of the same model with different learning rates:

# %%
experiment.Experiment(AlexNet_lr1e_5, AlexNet_lr3e_5, AlexNet_lr1e_4, AlexNet_lr3e_4).\
    lr_valacc5(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Learning Rates & Validation Accuracies (top 5).
#
# [Controlled Variables]
# model: AlexNet
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# epoch: 50
# batch size: 16
#
# learning rate: ['1e-05', '3e-05', '0.0001', '0.0003']
# validation accuracy (top 5):
# [0.36, 0.588, 0.706, 0.662, 0.735, 0.794, 0.772, 0.794, 0.846, 0.904, 0.89, 0.919, 0.912, 0.941, 0.941, 0.978, 0.926, 0.956, 0.926, 0.949, 0.949, 0.971, 0.949, 0.963, 0.963, 0.956, 0.956, 0.949, 0.971, 0.971, 0.956, 0.949, 0.978, 0.963, 0.978, 0.963, 0.985, 0.978, 0.985, 0.978, 0.978, 0.978, 0.978, 0.978, 0.971, 0.963, 0.985, 0.971, 0.985, 0.985]
# ...

# %% [markdown]
# ## 2.2 Models of different Batch Sizes

# %% [markdown]
# Load the trained models:

# %%
SwinTransformer_b4 = model.model.load_model (model.model_schema(), GP_setup, "SwinTransformer_lr1e-4_b4_e100")
SwinTransformer_b8 = model.model.load_model (model.model_schema(), GP_setup, "SwinTransformer_lr1e-4_b8_e100")
SwinTransformer_b16 = model.model.load_model (model.model_schema(), GP_setup, "SwinTransformer_lr1e-4_b16_e100")
SwinTransformer_b32 = model.model.load_model (model.model_schema(), GP_setup, "SwinTransformer_lr1e-4_b32_e100")
# Out:
# ...
# Load model SwinTransformer_lr1e-4_b4_e100 (SwinTransformer) successfully.
# ...
# Load model SwinTransformer_lr1e-4_b8_e100 (SwinTransformer) successfully.
# ...
# Load model SwinTransformer_lr1e-4_b16_e100 (SwinTransformer) successfully.
# ...
# Load model SwinTransformer_lr1e-4_b32_e100 (SwinTransformer) successfully.

# %% [markdown]
# ### Batch Sizes -> Train Losses

# %% [markdown]
# ------
#
# Evaluate the change of training losses of the same model with different batch sizes:

# %%
experiment.Experiment(SwinTransformer_b4, SwinTransformer_b8, SwinTransformer_b16, SwinTransformer_b32).\
    model_trainloss(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between models and Train Losses & Validation Accuracies (top 1 & top 5).
#
# ...
#
# Consider the above warning(s), press Enter to discard or enter anything to continue drawing the chart. 1
# [Controlled Variables]
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 0.0001
# epoch: 100
# batch size: 4
#
# train loss:
# ...

# %% [markdown]
# ### Batch Sizes -> Validation Accurcies (Top 1)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 1) of the same model with different batch sizes:

# %%
experiment.Experiment(SwinTransformer_b4, SwinTransformer_b8, SwinTransformer_b16, SwinTransformer_b32).\
    bs_valacc1(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Batch Sizes & Validation Accuracies (top 1).
#
# [Controlled Variables]
# model: SwinTransformer
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: ['4', '8', '16', '32']
# epoch: 100
#
# batch size: ['4', '8', '16', '32']
# validation accuracy (top 1):
# ...

# %% [markdown]
# ### Batch Sizes -> Validation Accurcies (Top 5)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 5) of the same model with different batch sizes:

# %%
experiment.Experiment(SwinTransformer_b4, SwinTransformer_b8, SwinTransformer_b16, SwinTransformer_b32).\
    bs_valacc5(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Batch Sizes & Validation Accuracies (top 5).
#
# [Controlled Variables]
# model: SwinTransformer
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: ['4', '8', '16', '32']
# epoch: 100
#
# batch size: ['4', '8', '16', '32']
# validation accuracy (top 5):
# ...

# %% [markdown]
# ## 2.3 Models of different Datasets

# %% [markdown]
# Load the trained models:

# %%
TNT = model.model.load_model (model.model_schema(), GP_setup, "TNT_lr1e-4_b16_e50")
TNT_aug = model.model.load_model (model.model_schema(), GP_setup, "TNT_lr1e-4_b16_e50_aug")
# Out:
# ...
# [Package] Download einops package successfully.
# Load model TNT_lr1e-4_b16_e50 (TNT) successfully.
# ...
# Load model TNT_lr1e-4_b16_e50_aug (TNT) successfully.

# %% [markdown]
# ### Datasets -> Train Losses

# %% [markdown]
# ------
#
# Evaluate the change of training losses of the same model with different datasets:

# %%
experiment.Experiment(TNT, TNT_aug).\
    model_trainloss(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between models and Train Losses & Validation Accuracies (top 1 & top 5).
#
# ...
#
# Consider the above warning(s), press Enter to discard or enter anything to continue drawing the chart. 1
# [Controlled Variables]
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 0.0001
# epoch: 50
# batch size: 16
#
# train loss:
# [198.647, 154.287, 127.972, 113.382, 106.968, 99.559, 92.831, 85.568, 79.408, 75.94, 72.063, 71.394, 64.894, 65.917, 63.809, 61.204, 55.353, 55.852, 53.38, 51.609, 50.623, 49.365, 46.846, 41.504, 41.637, 44.833, 40.136, 41.642, 39.81, 35.376, 36.738, 35.254, 31.872, 32.573, 28.643, 27.533, 29.07, 27.436, 26.812, 24.686, 24.497, 25.531, 25.967, 22.358, 23.715, 20.256, 21.455, 18.102, 18.596, 20.133]
# ...

# %% [markdown]
# ### Datasets -> Validation Accurcies (Top 1)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 1) of the same model with different datasets:

# %%
experiment.Experiment(TNT, TNT_aug).\
    ds_valacc1(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Datasets & Validation Accuracies (top 1).
#
# [Controlled Variables]
# model: TNT
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 0.0001
# epoch: 50
# batch size: 16
#
# dataset: ['Oxford_17', 'Oxford_17_Augmented']
# validation accuracy (top 1):
# [0.11, 0.346, 0.397, 0.426, 0.456, 0.434, 0.456, 0.544, 0.544, 0.596, 0.566, 0.566, 0.596, 0.662, 0.596, 0.647, 0.654, 0.654, 0.699, 0.618, 0.618, 0.669, 0.662, 0.721, 0.691, 0.706, 0.684, 0.662, 0.699, 0.721, 0.654, 0.669, 0.662, 0.676, 0.706, 0.713, 0.75, 0.691, 0.713, 0.684, 0.721, 0.684, 0.632, 0.721, 0.735, 0.743, 0.669, 0.625, 0.699, 0.721]
# ...

# %% [markdown]
# ### Datasets -> Validation Accurcies (Top 5)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 5) of the same model with different datasets:

# %%
experiment.Experiment(TNT, TNT_aug).\
    ds_valacc5(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Datasets & Validation Accuracies (top 5).
#
# [Controlled Variables]
# model: TNT
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 0.0001
# epoch: 50
# batch size: 16
#
# dataset: ['Oxford_17', 'Oxford_17_Augmented']
# validation accuracy (top 5):
# [0.404, 0.809, 0.838, 0.86, 0.875, 0.875, 0.912, 0.904, 0.956, 0.926, 0.934, 0.949, 0.963, 0.941, 0.934, 0.941, 0.941, 0.956, 0.963, 0.963, 0.963, 0.963, 0.941, 0.956, 0.949, 0.956, 0.949, 0.956, 0.956, 0.963, 0.963, 0.963, 0.956, 0.971, 0.963, 0.956, 0.941, 0.956, 0.971, 0.971, 0.971, 0.941, 0.941, 0.956, 0.963, 0.941, 0.949, 0.934, 0.934, 0.949]
# ...

# %% [markdown]
# ## 2.4 Models of different Backbones

# %% [markdown]
# Load the trained models:

# %%
AlexNet = model.model.load_model (model.model_schema(), GP_setup, "AlexNet_lr1e-4_b16_e50")
SwinTransformer = model.model.load_model (model.model_schema(), GP_setup, "SwinTransformer_lr1e-4_b16_e50")
VAN = model.model.load_model (model.model_schema(), GP_setup, "VAN_lr1e-4_b16_e50")
VisionTransformer = model.model.load_model (model.model_schema(), GP_setup, "VisionTransformer_lr1e-4_b16_e50")
# Out:
# ...
# Load model AlexNet_lr1e-4_b16_e50 (AlexNet) successfully.
# ...
# Load model SwinTransformer_lr1e-4_b16_e50 (SwinTransformer) successfully.
# ...
# Load model VAN_lr1e-4_b16_e50 (VAN) successfully.
# ...
# Load model VisionTransformer_lr1e-4_b16_e50 (VisionTransformer) successfully.

# %% [markdown]
# ### Backbones -> Train Losses

# %% [markdown]
# ------
#
# Evaluate the change of training losses of the same model with different backbones:

# %%
experiment.Experiment(AlexNet, SwinTransformer, VAN, VisionTransformer).\
    model_trainloss(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between models and Train Losses & Validation Accuracies (top 1 & top 5).
#
# [Controlled Variables]
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 0.0001
# epoch: 50
# batch size: 16
#
# train loss:
# [180.599, 159.852, 140.695, 124.167, 109.362, 94.567, 83.846, 74.357, 70.927, 66.311, 56.917, 53.586, 49.967, 42.642, 39.05, 38.185, 33.391, 30.566, 30.82, 25.61, 20.075, 25.008, 16.837, 19.975, 16.39, 22.187, 16.873, 14.55, 15.882, 16.011, 12.742, 9.592, 10.079, 9.348, 11.965, 9.144, 9.253, 9.329, 11.443, 8.371, 5.491, 3.947, 12.698, 5.331, 9.666, 19.612, 8.155, 3.381, 3.03, 2.095]
# ...

# %% [markdown]
# ### Backbones -> Validation Accurcies (Top 1)

# %% [markdown]
# Evaluate the change of validation accurcies (TOP 1) of the same model with different backbones:

# %%
experiment.Experiment(AlexNet, SwinTransformer, VAN, VisionTransformer).\
    model_valacc1(GP_setup, "color_schema")
# Out:
# [Experiment] Find the relationship between Models and Validation Accuracies (top 1 & top 5).
#
# [Controlled Variables]
# dataset: Oxford_17
# loss function: CrossEntropyLoss
# optimizer: Adam (momentum = None)
# learning rate: 0.0001
# epoch: 50
# batch size: 16
#
# validation accuracy (top 1):
# [0.154, 0.265, 0.316, 0.375, 0.478, 0.493, 0.551, 0.574, 0.603, 0.632, 0.603, 0.625, 0.676, 0.662, 0.706, 0.706, 0.654, 0.713, 0.75, 0.757, 0.757, 0.779, 0.735, 0.743, 0.691, 0.743, 0.757, 0.779, 0.75, 0.772, 0.824, 0.824, 0.794, 0.743, 0.787, 0.801, 0.743, 0.779, 0.772, 0.787, 0.794, 0.794, 0.765, 0.794, 0.632, 0.765, 0.779, 0.787, 0.801, 0.75]
# [0.132, 0.206, 0.368, 0.515, 0.419, 0.515, 0.529, 0.581, 0.654, 0.61, 0.699, 0.64, 0.603, 0.574, 0.669, 0.662, 0.713, 0.662, 0.728, 0.743, 0.735, 0.721, 0.743, 0.728, 0.779, 0.757, 0.713, 0.728, 0.772, 0.743, 0.706, 0.743, 0.765, 0.794, 0.787, 0.779, 0.735, 0.713, 0.75, 0.743, 0.801, 0.794, 0.809, 0.809, 0.772, 0.772, 0.816, 0.765, 0.765, 0.772]
# ...
